# %% [markdown]
# # Taking Observations

# %% [markdown]
# ### Wave propagation

# %%
import os
import numpy as np
# import matplotlib.pyplot as plt
# from matplotlib.colors import LogNorm

# %%
from medis.medis_main import RunMedis  # this is the top level function
from medis.plot_tools import quick2D, grid  # plotting single images or a grid of images
# from medis.twilight_colormaps import sunlight
from medis.params import params  # this is where all the default parameters are stored
from medis.utils import dprint  # this is just a useful function

# %% [markdown]
# Overwrite the parameters we care about

# %%
params['sp'].save_to_disk = False  # having this off is useful initially until we start running full sims
params['sp'].verbose = True
params['sp'].debug = True  # this will show the results at every optic for the star at the shortest wavelength
params['sp'].numframes = 1  # total number of time frames
params['sp'].sample_time = 0.5e-3  # time between time frames
params['sp'].grid_size = 512  # fairly wide grid to get good samplng of pupil planes 
params['sp'].star_flux = 1e9  # lets assume 1e9 photons across the array per second
params['sp'].beam_ratio = 0.1  # low value supresses the reflections in the focal plane
params['sp'].save_list = np.array(['atmosphere','detector'])

params['ap'].companion_xy = [[0.5,0]]  # this is 50 mas separation
params['ap'].contrast = [1e-3]  # this is 50 mas separation
params['ap'].companion = True
params['ap'].n_wvl_init = 1  # single band
params['tp'].cg_type = 'Vortex'  # occulter type
params['tp'].satelite_speck = False  # object to close to care about these
params['tp'].prescription = 'general_telescope' # 'Subaru_SCExAO'  # lets use general for now
params['tp'].obscure = False  # spiders and M2 obscurations off for now
params['tp'].use_ao = True

TESTDIR = 'demo'

# %% [markdown]
# First lets just intialise a simulation that generates ideal electric fields (no photon noise or dead pixels etc) for this system. This will create the top "test" directory if it does not already exist. If it does exist the params file will be checked against the requested parameters to see if they match (has not been fully verified yet)

# %%
sim = RunMedis(params=params, name=f'{TESTDIR}/justfields', product='fields')
# Out:
# 	 Astro_params
# {'C_spec': 1.5,
#  'companion': True,
#  'companion_xy': [[0.5, 0]],
#  'contrast': [0.001],
#  'interp_wvl': True,
#  'n_wvl_final': 5,
#  'n_wvl_init': 1,
#  'star_flux': 100000,
#  'wvl_range': array([8.0e-07, 1.5e-06])}
#
# 	 Telescope_params
# {'abertime': 0.5,
#  'ao_act': 60,
#  'array_size': array([129, 129]),
#  'cg_size': 3,
#  'cg_size_units': 'l/D',
#  'cg_type': 'Vortex',
#  'detector': 'ideal',
#  'entrance_d': 5,
#  'fit_dm': True,
#  'fl_cg_lens': 1000,
#  'flen_primary': 25,
#  'fnum_primary': 12,
#  'legs_frac': 0.03,
#  'lens_params': [{'aber_vals': [5e-18, 2.0, 3.1],
#                   'diam': 0.2,
#                   'dist': 1.345,
#                   'focal_length': 1.2,
#                   'name': 'CPA'},
#                  {'aber_vals': [5e-18, 2.0, 3.1],
#                   'diam': 0.2,
#                   'dist': 1.345,
#                   'focal_length': 1.2,
#                   'name': 'NCPA'}],
#  'lyot_size': 0.75,
#  'obscure': False,
#  'piston_error': False,
#  'pix_shift': [0, 0],
#  'prescription': 'general_telescope',
#  'satelite_speck': False,
#  'servo_error': [0, 1],
#  'use_ao': True,
#  'use_atmos': True,
#  'wavecal_coeffs': [83333333.33333333, -157],
#  'zernike_orders': [2, 3, 4],
#  'zernike_vals': array([ 1.75e-07, -1.50e-07,  2.00e-07])}
#
# 	 Atmos_params
# {'L0': 10,
#  'cn_sq': 2.2e-13,
#  'fried': 0.2,
#  'h': 100,
#  'model': 'single',
#  'vel': 5}
#
# 	 CDI_params
# {'n_probes': 8,
#  'null_time': 0.1,
#  'phase_integration_time': 0.01,
#  'phase_list': array([0.        , 0.78539816, 1.57079633, 2.35619449, 3.14159265,
#        3.92699082, 4.71238898, 5.49778714]),
#  'phs_intervals': 0.7853981633974483,
#  'probe_amp': 2e-05,
#  'probe_center': 15,
#  'probe_h': 20,
#  'probe_type': 'pairwise',
#  'probe_w': 20,
#  'show_probe': True,
#  'use_cdi': False}
#
# 	 IO_params
# {'aberdir': '/Users/dodkins/MKIDSim/demo/justfields/aberrations/gridsz{}_bmratio{}_tsteps{}',
#  'aberroot': 'aberrations',
#  'atmosdir': '/Users/dodkins/MKIDSim/demo/justfields/atmos/gridsz{}_bmratio{}_tsteps{}',
#  'atmosroot': 'atmos',
#  'camera': '/Users/dodkins/MKIDSim/demo/justfields/camera.pkl',
#  'datadir': '/Users/dodkins/MKIDSim/',
#  'device': '/Users/dodkins/MKIDSim/demo/justfields/device.pkl',
#  'fields': '/Users/dodkins/MKIDSim/demo/justfields/fields.h5',
#  'params_logs': '/Users/dodkins/MKIDSim/demo/justfields/params.pkl',
#  'prescopydir': '/Users/dodkins/MKIDSim/demo/justfields/prescription/{}',
#  'prescopyroot': 'prescription',
#  'prescriptions_root': '/Users/dodkins/PythonProjects/MEDIS++/simulations',
#  'telescope': '/Users/dodkins/MKIDSim/demo/justfields/telescope.pkl',
#  'testdir': '/Users/dodkins/MKIDSim/demo/justfields',
#  'testname': 'demo/justfields'}
#
# 	 Simulation_params
# {'ao_delay': False,
#  'beam_ratio': 0.1,
#  'checkpointing': None,
#  'chunking': True,
#  'closed_loop': False,
#  'continuous_save': True,
#  'debug': True,
#  'focused_sys': False,
#  'grid_size': 512,
#  'maskd_size': 256,
#  'memory_limit': 10,
#  'num_processes': 1,
#  'numframes': 1,
#  'parrallel': False,
#  'quick_companions': False,
#  'quick_detect': False,
#  'sample_time': 0.0005,
#  'save_list': array(['atmosphere', 'detector'], dtype='<U10'),
#  'save_to_disk': False,
#  'show_spectra': False,
#  'show_tseries': False,
#  'show_wframe': True,
#  'skip_planes': [],
#  'spectra_cols': 2,
#  'star_flux': 1000000000.0,
#  'startframe': 0,
#  'timing': True,
#  'tseries_cols': 2,
#  'verbose': True}
#
# 	 MKID_params
# {'QE_map': None,
#  'QE_var': False,
#  'R_mean': 50,
#  'R_sig': 2,
#  'R_spec': -0.1,
#  'array_size': array([129, 129]),
#  'bad_pix': False,
#  'bg_mean': 0,
#  'bg_sig': 30,
#  'bin_time': 0.002,
#  'dark_bright': 10,
#  'dark_counts': False,
#  'dark_pix_frac': 0.1,
#  'dead_time': 0.02,
#  'frame_int': 0.05,
#  'g_mean': 0.95,
#  'g_sig': 0.025,
#  'g_spec': -0.1,
#  'hot_bright': 1000.0,
#  'hot_pix': 0,
#  'lod': 8,
#  'max_count': 2500.0,
#  'nlod': 10,
#  'phase_background': False,
#  'phase_uncertainty': False,
#  'pix_yield': 0.9,
#  'platescale': 0.01,
#  'quantize_FCs': False,
#  'r_mean': 1,
#  'r_sig': 0.05,
#  'remove_close': False,
#  'res_elements': 129,
#  'resamp': True,
#  't_frames': 20,
#  'threshold_phase': 0,
#  'total_int': 1,
#  'wavecal_coeffs': [83333333.33333333, -157]}
# param: ap, match: True
# param: tp, match: True
# param: atmp, match: True
# param: cdip, match: True
# param: iop, match: True
# param: sp, match: True
# Configuration files match. Initialization over

# %% [markdown]
# Calling sim will begin the observation that generates the fields ndarray. It will create all the directories, atmosphere maps, aberration maps, coronagraph maps and check if the simulation needs to be chunked to fit into the dynamic memory or not

# %%
observation = sim()
# Out:
# Initialising new telescope instance
#
# Using prescription /Users/dodkins/PythonProjects/MEDIS++/simulations/general_telescope/general_telescope.py
# Prescription already exists at
#
# 	/Users/dodkins/MKIDSim/demo/justfields/prescription/general_telescope/general_telescope.py
#
# ... skipping copying
#
#
# Atmosphere maps already exist at
#
# 	/Users/dodkins/MKIDSim/demo/justfields/atmos/gridsz512_bmratio0.1_tsteps1
#
# ... skipping generation
#
#
# Aberration maps already exist at
#
# 	/Users/dodkins/MKIDSim/demo/justfields/aberrations/gridsz512_bmratio0.1_tsteps1
#
# ... skipping generation
#
#
# Each timestep is predicted to be 20.97152 MB, requiring sim to be split into 476.0 time chunks
# File total size should be 20.971519999999998 MB
# Using time chunks of size 1
#
#
# 	Beginning Telescope Simulation with MEDIS
# MEDIS++/medis/atmosphere.py:104 - Atmos map applied is /Users/dodkins/MKIDSim/demo/justfields/atmos/gridsz512_bmratio0.1_tsteps1/atmos_t0.000_single_wvl8.000e-07.fits
# MEDIS++/medis/atmosphere.py:104 - Atmos map applied is /Users/dodkins/MKIDSim/demo/justfields/atmos/gridsz512_bmratio0.1_tsteps1/atmos_t0.000_single_wvl8.000e-07.fits
# Zeroing outside the beam after atmosphere
# MEDIS++/medis/optics.py:176 - saving plane at atmosphere
# Zeroing outside the beam after CPA
# Zeroing outside the beam after deformable mirror
# Zeroing outside the beam after NCPA
# MEDIS++/medis/optics.py:176 - saving plane at detector
# Finished datacube at timestep = 0
#
#
# 	MEDIS Telescope Run Completed
#
# Time elapsed: 0.50 minutes
# Shape of cpx_sequence = timesteps:1, save planes:2, wavelengths:1, num obj:2, x:512, y:512

# %% [markdown]
# This demonstration shows a lot of reflections in the focal plane so perhaps the grid_size should be increased

# %% [markdown]
# From this dictionary we can look at the fields ndarray

# %%
print(observation.keys())
fields = observation['fields']
grid(np.angle(fields[0,0]), vlim=(-np.pi, np.pi), show=False, cmap='sunlight')
grid(fields[0,1], logZ=True, nstd=2, show=True)
# Out:
# dict_keys(['fields', 'sampling'])

# %% [markdown]
# ### Quantization

# %%
sim = RunMedis(params=params, name=f'{TESTDIR}/justfields', product='photons')
# Out:
# 	 Astro_params
# {'C_spec': 1.5,
#  'companion': True,
#  'companion_xy': [[0.5, 0]],
#  'contrast': [0.001],
#  'interp_wvl': True,
#  'n_wvl_final': 5,
#  'n_wvl_init': 1,
#  'star_flux': 100000,
#  'wvl_range': array([8.0e-07, 1.5e-06])}
#
# 	 Telescope_params
# {'abertime': 0.5,
#  'ao_act': 60,
#  'array_size': array([129, 129]),
#  'cg_size': 3,
#  'cg_size_units': 'l/D',
#  'cg_type': 'Vortex',
#  'detector': 'ideal',
#  'entrance_d': 5,
#  'fit_dm': True,
#  'fl_cg_lens': 1000,
#  'flen_primary': 25,
#  'fnum_primary': 12,
#  'legs_frac': 0.03,
#  'lens_params': [{'aber_vals': [5e-18, 2.0, 3.1],
#                   'diam': 0.2,
#                   'dist': 1.345,
#                   'focal_length': 1.2,
#                   'name': 'CPA'},
#                  {'aber_vals': [5e-18, 2.0, 3.1],
#                   'diam': 0.2,
#                   'dist': 1.345,
#                   'focal_length': 1.2,
#                   'name': 'NCPA'}],
#  'lyot_size': 0.75,
#  'obscure': False,
#  'piston_error': False,
#  'pix_shift': [0, 0],
#  'prescription': 'general_telescope',
#  'satelite_speck': False,
#  'servo_error': [0, 1],
#  'use_ao': True,
#  'use_atmos': True,
#  'wavecal_coeffs': [83333333.33333333, -157],
#  'zernike_orders': [2, 3, 4],
#  'zernike_vals': array([ 1.75e-07, -1.50e-07,  2.00e-07])}
#
# 	 Atmos_params
# {'L0': 10,
#  'cn_sq': 2.2e-13,
#  'fried': 0.2,
#  'h': 100,
#  'model': 'single',
#  'vel': 5}
#
# 	 CDI_params
# {'n_probes': 8,
#  'null_time': 0.1,
#  'phase_integration_time': 0.01,
#  'phase_list': array([0.        , 0.78539816, 1.57079633, 2.35619449, 3.14159265,
#        3.92699082, 4.71238898, 5.49778714]),
#  'phs_intervals': 0.7853981633974483,
#  'probe_amp': 2e-05,
#  'probe_center': 15,
#  'probe_h': 20,
#  'probe_type': 'pairwise',
#  'probe_w': 20,
#  'show_probe': True,
#  'use_cdi': False}
#
# 	 IO_params
# {'aberdir': '/Users/dodkins/MKIDSim/demo/justfields/aberrations/gridsz{}_bmratio{}_tsteps{}',
#  'aberroot': 'aberrations',
#  'atmosdir': '/Users/dodkins/MKIDSim/demo/justfields/atmos/gridsz{}_bmratio{}_tsteps{}',
#  'atmosroot': 'atmos',
#  'camera': '/Users/dodkins/MKIDSim/demo/justfields/camera.pkl',
#  'datadir': '/Users/dodkins/MKIDSim/',
#  'device': '/Users/dodkins/MKIDSim/demo/justfields/device.pkl',
#  'fields': '/Users/dodkins/MKIDSim/demo/justfields/fields.h5',
#  'params_logs': '/Users/dodkins/MKIDSim/demo/justfields/params.pkl',
#  'prescopydir': '/Users/dodkins/MKIDSim/demo/justfields/prescription/{}',
#  'prescopyroot': 'prescription',
#  'prescriptions_root': '/Users/dodkins/PythonProjects/MEDIS++/simulations',
#  'telescope': '/Users/dodkins/MKIDSim/demo/justfields/telescope.pkl',
#  'testdir': '/Users/dodkins/MKIDSim/demo/justfields',
#  'testname': 'demo/justfields'}
#
# 	 Simulation_params
# {'ao_delay': False,
#  'beam_ratio': 0.1,
#  'checkpointing': None,
#  'chunking': True,
#  'closed_loop': False,
#  'continuous_save': True,
#  'debug': True,
#  'focused_sys': False,
#  'grid_size': 512,
#  'maskd_size': 256,
#  'memory_limit': 10,
#  'num_processes': 1,
#  'numframes': 1,
#  'parrallel': False,
#  'quick_companions': False,
#  'quick_detect': False,
#  'sample_time': 0.0005,
#  'save_list': array(['atmosphere', 'detector'], dtype='<U10'),
#  'save_to_disk': False,
#  'show_spectra': False,
#  'show_tseries': False,
#  'show_wframe': True,
#  'skip_planes': [],
#  'spectra_cols': 2,
#  'star_flux': 1000000000.0,
#  'startframe': 0,
#  'timing': True,
#  'tseries_cols': 2,
#  'verbose': True}
#
# 	 MKID_params
# {'QE_map': None,
#  'QE_var': False,
#  'R_mean': 50,
#  'R_sig': 2,
#  'R_spec': -0.1,
#  'array_size': array([129, 129]),
#  'bad_pix': False,
#  'bg_mean': 0,
#  'bg_sig': 30,
#  'bin_time': 0.002,
#  'dark_bright': 10,
#  'dark_counts': False,
#  'dark_pix_frac': 0.1,
#  'dead_time': 0.02,
#  'frame_int': 0.05,
#  'g_mean': 0.95,
#  'g_sig': 0.025,
#  'g_spec': -0.1,
#  'hot_bright': 1000.0,
#  'hot_pix': 0,
#  'lod': 8,
#  'max_count': 2500.0,
#  'nlod': 10,
#  'phase_background': False,
#  'phase_uncertainty': False,
#  'pix_yield': 0.9,
#  'platescale': 0.01,
#  'quantize_FCs': False,
#  'r_mean': 1,
#  'r_sig': 0.05,
#  'remove_close': False,
#  'res_elements': 129,
#  'resamp': True,
#  't_frames': 20,
#  'threshold_phase': 0,
#  'total_int': 1,
#  'wavecal_coeffs': [83333333.33333333, -157]}
# param: ap, match: True
# param: tp, match: True
# param: atmp, match: True
# param: cdip, match: True
# param: iop, match: True
# param: sp, match: True
# Configuration files match. Initialization over
